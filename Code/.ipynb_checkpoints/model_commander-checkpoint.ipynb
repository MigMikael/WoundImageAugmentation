# %%
from model import ColorCalibrationModel as ccm
import time

train_path = "../Data/s8_motoC/s8_motoC_train_data.txt"
test_path = "../Data/s8_motoC/s8_motoC_test_data.txt"

saved_path = "./saved_model/saved_model_exp_8/"

parameter_path = "./parameter_set/exp_8/"
name = "set-"
extension = ".txt"

data_path = '../Output/output_exp_8/'

for i in range(120):
    parameter_file_name = name + str(i+1) + extension
    
    #print(parameter_file_name)

    hidden_layers_dim = 0
    learning_rate = 0
    minibatch_size = 0
    num_train_samples_per_sweep = 0
    num_test_samples = 0

    with open(parameter_path + parameter_file_name, 'r') as datafile:
        for line in datafile:
            p = line.split('=')
            if p[0] == "hidden_layers_dim":
                hidden_layers_dim = int(p[1])
            elif p[0] == "learning_rate":
                learning_rate = float(p[1])
            elif p[0] == "minibatch_size":
                minibatch_size = int(p[1])
            elif p[0] == "num_train_samples_per_sweep":
                num_train_samples_per_sweep = int(p[1])
            elif p[0] == "num_test_samples":
                num_test_samples = int(p[1])
                
    result_name = 'result-'+ name + str(i + 1) + "-"
    file_extension = '.txt'
    result_file_name = data_path + result_name + str(time.ctime()) + file_extension

    neural_net = ccm(train_path, test_path)
    neural_net.start(hidden_layers_dim, learning_rate, minibatch_size, num_train_samples_per_sweep, num_test_samples, result_file_name)
    neural_net.save_model(saved_path + "model-" + name + str(i + 1) +'.model')
    print("Finish "+ parameter_file_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-90d7ead3dc72> in <module>()
#      42     result_file_name = data_path + result_name + str(time.ctime()) + file_extension
#      43
# ---> 44     neural_net = ccm(train_path, test_path)
#      45     neural_net.start(hidden_layers_dim, learning_rate, minibatch_size, num_train_samples_per_sweep, num_test_samples, result_file_name)
#      46     neural_net.save_model(saved_path + "model-" + name + str(i + 1) +'.model')
#
# ~/thesis/WoundImageAugmentation/Code/model.py in __init__(self, path_train, path_test)
#       9 class ColorCalibrationModel:
#      10     def __init__(self, path_train, path_test):
# ---> 11         try_set_default_device(gpu(0))
#      12         self.path_train = path_train
#      13         self.path_test = path_test
#
# ~/anaconda3/envs/thesis-env2/lib/python3.6/site-packages/cntk/internal/swig_helper.py in wrapper(*args, **kwds)
#      67     @wraps(f)
#      68     def wrapper(*args, **kwds):
# ---> 69         result = f(*args, **kwds)
#      70         map_if_possible(result)
#      71         return result
#
# ~/anaconda3/envs/thesis-env2/lib/python3.6/site-packages/cntk/device.py in gpu(device_id)
#      94         :class:`~cntk.device.DeviceDescriptor`: GPU device descriptor
#      95     '''
# ---> 96     return cntk_py.DeviceDescriptor.gpu_device(device_id)
#      97
#      98
#
# ValueError: Specified GPU device id (0) is invalid.
#
# [CALL STACK]
# [0x7f0cf1c17d5c]                                                       + 0x682d5c
# [0x7f0cf1c1424c]    CNTK::DeviceDescriptor::  GPUDevice  (unsigned int) + 0xcc
# [0x7f0cf83d02d9]                                                       + 0xae2d9
# [0x55e885d1f681]    _PyCFunction_FastCallDict                          + 0x91
# [0x55e885dad93c]                                                       + 0x19c93c
# [0x55e885dd1a7a]    _PyEval_EvalFrameDefault                           + 0x2fa
# [0x55e885da8489]    PyEval_EvalCodeEx                                  + 0x329
# [0x55e885da93b6]                                                       + 0x1983b6
# [0x55e885d1f54e]    PyObject_Call                                      + 0x3e
# [0x55e885dd334e]    _PyEval_EvalFrameDefault                           + 0x1bce
# [0x55e885da6c56]                                                       + 0x195c56
# [0x55e885da7971]                                                       + 0x196971
# [0x55e885dada15]                                                       + 0x19ca15
# [0x55e885dd1a7a]    _PyEval_EvalFrameDefault                           + 0x2fa
# [0x55e885da7dab]    _PyFunction_FastCallDict                           + 0x11b
# [0x55e885d1fb0f]    _PyObject_FastCallDict                             + 0x26f
# [0x55e885d24723]    _PyObject_Call_Prepend                             + 0x63
# [0x55e885d1f54e]    PyObject_Call                                      + 0x3e
# [0x55e885d7b09b]                                                       + 0x16a09b
# [0x55e885dadc77]                                                       + 0x19cc77
# [0x55e885d1f92b]    _PyObject_FastCallDict                             + 0x8b
# [0x55e885dada8e]                                                       + 0x19ca8e
# [0x55e885dd1a7a]    _PyEval_EvalFrameDefault                           + 0x2fa
# [0x55e885